# %%
import numpy as np
import neurolab as nl
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('dry_bean.csv')
data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
data=data.dropna()
data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lc=LabelEncoder()
data['Class']=lc.fit_transform(data['Class'])
data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#        Class
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 13606      3
# 13607      3
# 13608      3
# 13609      3
# 13610      3
#
# [13611 rows x 17 columns]

# %%
X = data.drop(data.columns[-1], axis=1).values
y = data[data.columns[16:17]].values

# %%
X
# Out:
# array([[2.83950000e+04, 6.10291000e+02, 2.08178117e+02, ...,
#         3.14728900e-03, 8.34222388e-01, 9.98723889e-01],
#        [2.87340000e+04, 6.38018000e+02, 2.00524796e+02, ...,
#         3.56362400e-03, 9.09850506e-01, 9.98430331e-01],
#        [2.93800000e+04, 6.24110000e+02, 2.12826130e+02, ...,
#         3.04773300e-03, 8.25870617e-01, 9.99066137e-01],
#        ...,
#        [4.21390000e+04, 7.59321000e+02, 2.81539928e+02, ...,
#         1.88827100e-03, 6.76884164e-01, 9.96767264e-01],
#        [4.21470000e+04, 7.63779000e+02, 2.83382636e+02, ...,
#         1.85202500e-03, 6.68236684e-01, 9.95222420e-01],
#        [4.21590000e+04, 7.72237000e+02, 2.95142741e+02, ...,
#         1.63981200e-03, 6.16220592e-01, 9.98179623e-01]])

# %%
y
# Out:
# array([[5],
#        [5],
#        [5],
#        ...,
#        [3],
#        [3],
#        [3]])

# %%
X
# Out:
# array([[2.83950000e+04, 6.10291000e+02, 2.08178117e+02, ...,
#         3.14728900e-03, 8.34222388e-01, 9.98723889e-01],
#        [2.87340000e+04, 6.38018000e+02, 2.00524796e+02, ...,
#         3.56362400e-03, 9.09850506e-01, 9.98430331e-01],
#        [2.93800000e+04, 6.24110000e+02, 2.12826130e+02, ...,
#         3.04773300e-03, 8.25870617e-01, 9.99066137e-01],
#        ...,
#        [4.21390000e+04, 7.59321000e+02, 2.81539928e+02, ...,
#         1.88827100e-03, 6.76884164e-01, 9.96767264e-01],
#        [4.21470000e+04, 7.63779000e+02, 2.83382636e+02, ...,
#         1.85202500e-03, 6.68236684e-01, 9.95222420e-01],
#        [4.21590000e+04, 7.72237000e+02, 2.95142741e+02, ...,
#         1.63981200e-03, 6.16220592e-01, 9.98179623e-01]])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (9527, 16)
# (4084, 16)

# %%
input_size = X_train.shape[1]
output_size = y_train.shape[1]

# %%
input_size
# Out:
# 16

# %%
output_size
# Out:
# 1

# %%
min_val=[]
max_val=[]

# %%
column=data.columns
for i in range(len(column)):
    min_val.append(min(data[column[i]].tolist()))
    max_val.append(max(data[column[i]].tolist()))
inp=list(zip(min_val,max_val))
print(inp)
# Out:
# [(20420, 254616), (524.736, 1985.37), (183.601165, 738.8601535), (122.5126535, 460.1984968), (1.024867596, 2.430306447), (0.218951263, 0.911422968), (20684, 263261), (161.2437642, 569.3743583), (0.555314717, 0.866194641), (0.919246157, 0.9946775), (0.489618256, 0.9906854), (0.640576759, 0.987302969), (0.002778013, 0.010451169), (0.000564169, 0.003664972), (0.410338584, 0.974767153), (0.947687403, 0.99973253), (0, 6)]

# %%
input_size=[]
for i in inp:
    input_size.append(list(i))
input_size=input_size[:-1]
print(input_size)
# Out:
# [[20420, 254616], [524.736, 1985.37], [183.601165, 738.8601535], [122.5126535, 460.1984968], [1.024867596, 2.430306447], [0.218951263, 0.911422968], [20684, 263261], [161.2437642, 569.3743583], [0.555314717, 0.866194641], [0.919246157, 0.9946775], [0.489618256, 0.9906854], [0.640576759, 0.987302969], [0.002778013, 0.010451169], [0.000564169, 0.003664972], [0.410338584, 0.974767153], [0.947687403, 0.99973253]]

# %%
model1 = nl.net.newff(input_size,[16,1])

# %%
model1.trainf = nl.train.train_rprop

# %%
error1=[]

# %%
X_train
# Out:
# array([[3.02100000e+04, 6.51194000e+02, 2.54800257e+02, ...,
#         1.82621200e-03, 5.92462846e-01, 9.97174325e-01],
#        [2.69890000e+04, 6.03446000e+02, 2.09236366e+02, ...,
#         2.94628900e-03, 7.84914904e-01, 9.95539031e-01],
#        [7.95080000e+04, 1.12035100e+03, 4.10471774e+02, ...,
#         1.14963800e-03, 6.00833793e-01, 9.93229552e-01],
#        ...,
#        [9.00040000e+04, 1.15659900e+03, 4.56836383e+02, ...,
#         9.44017000e-04, 5.49098885e-01, 9.94035335e-01],
#        [3.84260000e+04, 7.11412000e+02, 2.46696608e+02, ...,
#         2.55938500e-03, 8.03912792e-01, 9.98825538e-01],
#        [6.36280000e+04, 9.97390000e+02, 4.00784151e+02, ...,
#         9.88363000e-04, 5.04356140e-01, 9.90707337e-01]])

# %%
from sklearn.metrics import accuracy_score

# %%
error1=[model1.train(X_train,y_train,epochs=100,show=2)]
# Out:
# Epoch: 2; Error: 46493.14797703022;
# Epoch: 4; Error: 46301.858748588864;
# Epoch: 6; Error: 46301.50004220648;
# Epoch: 8; Error: 46301.5000000001;
# Epoch: 10; Error: 46301.5;
# Epoch: 12; Error: 46301.5;
# Epoch: 14; Error: 46301.5;
# Epoch: 16; Error: 46301.5;
# Epoch: 18; Error: 46301.5;
# Epoch: 20; Error: 46301.5;
# Epoch: 22; Error: 46301.5;
# Epoch: 24; Error: 46301.5;
# Epoch: 26; Error: 46301.5;
# Epoch: 28; Error: 46301.5;
# Epoch: 30; Error: 46301.5;
# Epoch: 32; Error: 46301.5;
# Epoch: 34; Error: 46301.5;
# Epoch: 36; Error: 46301.5;
# Epoch: 38; Error: 46301.5;
# Epoch: 40; Error: 46301.5;
# Epoch: 42; Error: 46301.5;
# Epoch: 44; Error: 46301.5;
# Epoch: 46; Error: 46301.5;
# Epoch: 48; Error: 46301.5;
# Epoch: 50; Error: 46301.5;
# Epoch: 52; Error: 46301.5;
# Epoch: 54; Error: 46301.5;
# Epoch: 56; Error: 46301.5;
# Epoch: 58; Error: 46301.5;
# Epoch: 60; Error: 46301.5;
# Epoch: 62; Error: 46301.5;
# Epoch: 64; Error: 46301.5;
# Epoch: 66; Error: 46301.5;
# Epoch: 68; Error: 46301.5;
# Epoch: 70; Error: 46301.5;
# Epoch: 72; Error: 46301.5;
# Epoch: 74; Error: 46301.5;
# Epoch: 76; Error: 46301.5;
# Epoch: 78; Error: 46301.5;
# Epoch: 80; Error: 46301.5;
# Epoch: 82; Error: 46301.5;
# Epoch: 84; Error: 46301.5;
# Epoch: 86; Error: 46301.5;
# Epoch: 88; Error: 46301.5;
# Epoch: 90; Error: 46301.5;
# Epoch: 92; Error: 46301.5;
# Epoch: 94; Error: 46301.5;
# Epoch: 96; Error: 46301.5;
# Epoch: 98; Error: 46301.5;
# Epoch: 100; Error: 46301.5;
# The maximum number of train epochs is reached

# %%
y_pred1 = model1.sim(X_test)

# %%
print(y_pred1)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
x=np.unique(y_pred1)
x

# %%
classes=y_pred1
classes[y_pred1< 0.42781104]=0
classes[y_pred1>= 0.42781104]=1
print(accuracy_score(y_test,classes))
# Out:
# 0.03942213516160627

# %%
import pylab as pl
pl.plot(error1[0])
pl.xlabel('Epoch number')
pl.ylabel('Train error')
pl.grid()
pl.show()
